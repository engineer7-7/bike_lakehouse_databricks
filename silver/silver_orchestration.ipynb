# %%
silver_configs = [
    "crm/silver_crm_cust_info",
    "crm/silver_crm_prd_info",
    "crm/silver_crm_sales_details",
    "erp/silver_erp_customer_az12",
    "erp/silver_erp_loc_a101",
    "erp/silver_erp_px_cat_g1v2"
]

# %%
for file in silver_configs:
    dbutils.notebook.run(file, 3600)
    print(f'{file} run succesfully.')
