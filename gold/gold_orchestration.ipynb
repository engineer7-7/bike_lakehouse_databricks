# %%
gold_confings = [
    'gold_dim_customers',
    'gold_dim_product',
    'gold_fact_sales'
]

# %%
for file in gold_confings:
    dbutils.notebook.run(file, 3600)
    print(f'{file} run succesfully.')
