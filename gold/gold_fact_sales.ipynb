# %%
df_gold_sales = spark.table(
   "silver.crm_sales_details_info"
)

# %%
df_gold_sales.display()

# %%
# %sql
SELECT *
FROM silver.crm_sales_details_info
WHERE product_key IS NULL OR customer_id IS NULL;

# %% [markdown]
# - Extract it as gold table

# %%
df_gold_sales.write.format("delta").mode("overwrite").saveAsTable("gold.fact_sales")
